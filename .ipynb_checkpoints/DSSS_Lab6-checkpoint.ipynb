# %% [markdown]
# # Import dependencies

# %%
import pandas as pd
import numpy as np
import json
import io
import datetime as dt
import string
import unicodedata

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')

import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()
# nlp = spacy.load('en_core', parse=True, tag=True, entity=True)

import re
from bs4 import BeautifulSoup


from gensim import corpora, models, similarities

#nlp_vec = spacy.load('en_vecs', parse = True, tag=True, #entity=True)

# %% [markdown]
# # Read in data

# %%
#create dataframe from input data; identify the column with the tweet text
df=pd.read_csv('Tweets.csv')
print('Number of observations are: '+str(len(df)))
# Out:
# Number of observations are: 14640

# %%
#remove any rows that has no tweet text
df=df.text.dropna()
df = df.reset_index(drop=True)
print('Number of observations are: '+str(len(df)))
# Out:
# Number of observations are: 14640

# %%
#Create dictionary of all tweets
tweet_dictionary = {}
i = 0
for line in df:
        tweet_dictionary[i] = line.lower()
        i += 1
print(tweet_dictionary[1])
# Out:
# @virginamerica plus you've added commercials to the experience... tacky.

# %% [markdown]
# # Data Preprocessing I

# %% [markdown]
# Remove HTML Links

# %%
def strip_links(text):
    link_regex    = re.compile('((https?):((//)|(\\\\))+([\w\d:#@%/;$()~_?\+-=\\\.&](#!)?)*)', re.DOTALL)
    links         = re.findall(link_regex, text)
    for link in links:
        text = text.replace(link[0], ', ')    
    return text

# %%
for i in range(0,len(tweet_dictionary)):
    tweet_dictionary[i]=strip_links(tweet_dictionary[i])

# %% [markdown]
# Remove mentions

# %%
def strip_mentions(text):
    entity_prefixes = ['@']
    for separator in  string.punctuation:
        if separator not in entity_prefixes :
            text = text.replace(separator,' ')
    words = []
    for word in text.split():
        word = word.strip()
        if word:
            if word[0] not in entity_prefixes:
                words.append(word)
    return ' '.join(words)

# %%
for i in range(0,len(tweet_dictionary)):
    tweet_dictionary[i]=strip_mentions(tweet_dictionary[i])

# %% [markdown]
# Remove hashtags

# %%
def strip_hashtags(text):
    entity_prefixes = ['#']
    for separator in  string.punctuation:
        if separator not in entity_prefixes :
            text = text.replace(separator,' ')
    words = []
    for word in text.split():
        word = word.strip()
        if word:
            if word[0] not in entity_prefixes:
                words.append(word)
    return ' '.join(words)

# %%
for i in range(0,len(tweet_dictionary)):
    tweet_dictionary[i]=strip_hashtags(tweet_dictionary[i])

# %% [markdown]
# Remove retweet (RT) designation

# %%
for i in range(0,len(df)):
    tweet_dictionary[i] = tweet_dictionary[i].replace('RT', '')

# %% [markdown]
# # Data Preprocessing II

# %% [markdown]
# Expand contractions

# %%
#code source is http://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python

import re
cList = {
  "ain't": "am not",
  "aren't": "are not",
  "can't": "cannot",
  "can't've": "cannot have",
  "'cause": "because",
  "could've": "could have",
  "couldn't": "could not",
  "couldn't've": "could not have",
  "didn't": "did not",
  "doesn't": "does not",
  "don't": "do not",
  "hadn't": "had not",
  "hadn't've": "had not have",
  "hasn't": "has not",
  "haven't": "have not",
  "he'd": "he would",
  "he'd've": "he would have",
  "he'll": "he will",
  "he'll've": "he will have",
  "he's": "he is",
  "how'd": "how did",
  "how'd'y": "how do you",
  "how'll": "how will",
  "how's": "how is",
  "I'd": "I would",
  "I'd've": "I would have",
  "I'll": "I will",
  "I'll've": "I will have",
  "I'm": "I am",
  "I've": "I have",
  "isn't": "is not",
  "it'd": "it had",
  "it'd've": "it would have",
  "it'll": "it will",
  "it'll've": "it will have",
  "it's": "it is",
  "let's": "let us",
  "ma'am": "madam",
  "mayn't": "may not",
  "might've": "might have",
  "mightn't": "might not",
  "mightn't've": "might not have",
  "must've": "must have",
  "mustn't": "must not",
  "mustn't've": "must not have",
  "needn't": "need not",
  "needn't've": "need not have",
  "o'clock": "of the clock",
  "oughtn't": "ought not",
  "oughtn't've": "ought not have",
  "shan't": "shall not",
  "sha'n't": "shall not",
  "shan't've": "shall not have",
  "she'd": "she would",
  "she'd've": "she would have",
  "she'll": "she will",
  "she'll've": "she will have",
  "she's": "she is",
  "should've": "should have",
  "shouldn't": "should not",
  "shouldn't've": "should not have",
  "so've": "so have",
  "so's": "so is",
  "that'd": "that would",
  "that'd've": "that would have",
  "that's": "that is",
  "there'd": "there had",
  "there'd've": "there would have",
  "there's": "there is",
  "they'd": "they would",
  "they'd've": "they would have",
  "they'll": "they will",
  "they'll've": "they will have",
  "they're": "they are",
  "they've": "they have",
  "to've": "to have",
  "wasn't": "was not",
  "we'd": "we had",
  "we'd've": "we would have",
  "we'll": "we will",
  "we'll've": "we will have",
  "we're": "we are",
  "we've": "we have",
  "weren't": "were not",
  "what'll": "what will",
  "what'll've": "what will have",
  "what're": "what are",
  "what's": "what is",
  "what've": "what have",
  "when's": "when is",
  "when've": "when have",
  "where'd": "where did",
  "where's": "where is",
  "where've": "where have",
  "who'll": "who will",
  "who'll've": "who will have",
  "who's": "who is",
  "who've": "who have",
  "why's": "why is",
  "why've": "why have",
  "will've": "will have",
  "won't": "will not",
  "won't've": "will not have",
  "would've": "would have",
  "wouldn't": "would not",
  "wouldn't've": "would not have",
  "y'all": "you all",
  "y'alls": "you alls",
  "y'all'd": "you all would",
  "y'all'd've": "you all would have",
  "y'all're": "you all are",
  "y'all've": "you all have",
  "you'd": "you had",
  "you'd've": "you would have",
  "you'll": "youyou will",
  "you'll've": "you will have",
  "you're": "you are",
  "you've": "you have"
}

c_re = re.compile('(%s)' % '|'.join(cList.keys()))

def expandContractions(text, c_re=c_re):
    def replace(match):
        return cList[match.group(0)]
    text = c_re.sub(replace, text.lower())
    return text

# %%
for i in range(0,len(tweet_dictionary)):
    tweet_dictionary[i]=expandContractions(tweet_dictionary[i])

# %% [markdown]
# Remove spcial or accented characters (and maybe numbers)

# %%
def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-z0-9\s]' if not remove_digits else r'[^a-zA-z\s]'
    text = re.sub(pattern, '', text)
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

# %%
for i in range(0,len(tweet_dictionary)):
    tweet_dictionary[i]=remove_special_characters(tweet_dictionary[i], 
                          remove_digits=True)

# %% [markdown]
# Stopwords

# %%
def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

# %%
for i in range(0,len(tweet_dictionary)):
    tweet_dictionary[i]=remove_stopwords(tweet_dictionary[i])

# %% [markdown]
# Stemming / Lemming

# %%
def simple_stemmer(text):
    ps = nltk.porter.PorterStemmer()
    text = ' '.join([ps.stem(word) for word in text.split()])
    return text

# %%
def lemmatize_text(text):
    text = nlp(text)
    text = ' '.join([word.lemma_ if word.lemma_ != '-PRON-' else word.text for word in text])
    return text

# %%
for i in range(0,len(tweet_dictionary)):
    tweet_dictionary[i]=simple_stemmer(tweet_dictionary[i])
    #tweet_dictionary[i]=lemmatize_text(tweet_dictionary[i])

# %% [markdown]
# Tokenization

# %%
#Create corupus of all words
words_corpus = []
for i in range(0,len(tweet_dictionary)):
        words_corpus.append([word for word in tweet_dictionary[i].lower().split() if len(word)>3])
print(words_corpus)
# Out:
# [['said'], ['commerci', 'experi', 'tacki'], ['today', 'must', 'mean', 'need', 'take', 'anoth', 'trip'], ['realli', 'aggress', 'blast', 'obnoxi', 'entertain', 'guest', 'face', 'littl', 'recours'], ['realli', 'thing'], ['serious', 'would', 'flight', 'seat', 'play', 'realli', 'thing'], ['nearli', 'everi', 'time', 'worm', 'wont', 'away'], ['realli', 'miss', 'prime', 'opportun', 'without', 'parodi'], ['well', 'tbut'], ['amaz', 'arriv', 'hour', 'earli', 'good'], ['know', 'suicid', 'second', 'lead', 'caus', 'death', 'among', 'teen'], ['pretti', 'graphic', 'much', 'better', 'minim', 'iconographi'], ['great', 'deal', 'alreadi', 'think', 'trip', 'even', 'gone', 'trip'], ['fabul', 'seduct', 'take', 'stress', 'away', 'travel'], ['thank'], ['schedul', 'still'], ['excit', 'first', 'cross', 'countri', 'flight', 'heard', 'noth', 'great', 'thing', 'virgin', 'america', 'daystogo'], ['flew', 'last', 'week', 'fulli', 'seat', 'larg', 'gentleman', 'either', 'side', 'help'], [], ['know', 'would', 'amazingli', 'awesom', 'pleas', 'want'], ['first', 'fare', 'three', 'time', 'carrier', 'seat', 'avail', 'select'], ['love', 'graphic'], ['love', 'hipster', 'innov', 'feel', 'good', 'brand'], ['make', 'stop', 'perman', 'anytim', 'soon'], ['mess', 'seat', 'reserv', 'seat', 'friend', 'gave', 'seat', 'away', 'want', 'free', 'internet'], ['statu', 'match', 'program', 'appli', 'three', 'week', 'call', 'email', 'respons'], ['happen', 'vegan', 'food', 'option', 'least', 'site', 'know', 'anyth', 'next', 'fail'], ['miss', 'worri', 'togeth', 'soon'], ['amaz', 'cold', 'vent', 'noair', 'worstflightev', 'roast', 'sfotobo'], ['middl', 'seat', 'noob', 'maneuv', 'sendambien', 'andchexmix'], ['bked', 'cool', 'birthday', 'trip', 'elev', 'caus', 'enter', 'middl', 'name', 'flight', 'book', 'problem'], ['hour', 'oper', 'club', 'post', 'onlin', 'current'], ['help', 'left', 'expens', 'headphon', 'flight', 'today', 'seat', 'answer', 'number'], ['await', 'return', 'phone', 'call', 'would', 'prefer', 'onlin', 'self', 'servic', 'option'], ['great', 'news', 'america', 'could', 'start', 'flight', 'hawaii', 'year'], ['nice', 'vibe', 'moodlight', 'takeoff', 'touchdown', 'moodlitmonday', 'sciencebehindtheexperi'], ['moodlight', 'best', 'experi', 'ever', 'cool', 'calm', 'moodlitmonday'], ['done', 'done', 'best', 'airlin', 'around', 'hand'], ['book', 'flight', 'hawaii'], ['chat', 'support', 'work', 'site'], ['view', 'downtown', 'angel', 'hollywood', 'sign', 'beyond', 'rain', 'mountain'], ['first', 'time', 'flyer', 'next', 'week', 'excit', 'hard', 'time', 'flight', 'elev', 'account', 'help'], ['help', 'upgrad', 'flight'], ['unus', 'ticket', 'move', 'citi', 'expir', 'travelhelp'], ['flight', 'leav', 'dalla', 'seattl', 'time'], ['elevategold', 'good', 'reason', 'rock'], ['dream'], ['blew', 'mind'], ['last', 'night', 'tribut', 'soundofmus', 'oscar', 'think', 'agre'], ['entertain'], ['flight', 'suppos', 'take', 'minut', 'websit', 'still', 'show', 'time', 'flight', 'thank'], ['juli', 'andrew', 'though', 'impress'], ['wish', 'flew', 'atlanta', 'soon'], ['juli', 'andrew', 'hand'], ['flight', 'leav', 'dalla', 'februari'], ['excit', 'deal', 'book', 'sinc', 'last', 'week', 'page', 'never', 'load'], ['know', 'need', 'spotifi', 'stat', 'guiltypleasur'], ['ladi', 'gaga', 'amaz'], ['carri'], ['market', 'song', 'know', 'think'], ['juli', 'andrew', 'first', 'ladi', 'gaga', 'last', 'night', 'carri'], ['call', 'week', 'flight', 'elev', 'still', 'shown', 'help'], ['great', 'carrieunderwood'], ['sorri', 'mari', 'martin', 'first'], ['love', 'three', 'realli', 'beat', 'classic'], ['flight', 'check', 'could', 'statu', 'pleas'], ['heyyyi', 'guyyyi', 'hour', 'someon', 'call', 'pleas'], ['virgin', 'hold', 'minut', 'earlier', 'flight', 'tonight', 'earlier'], ['congrat', 'award', 'best', 'deal', 'airlin'], ['everyth', 'fine', 'lost'], ['need', 'chang', 'reserv', 'virgin', 'credit', 'card', 'need', 'modifi', 'phone', 'waiv', 'chang', 'onlin'], ['email', 'custom', 'servic', 'team', 'know', 'need', 'track', 'number'], ['bo ...

# %%
dictionary = corpora.Dictionary(words_corpus)
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)
# no_below is minimum number of documents
# no_above is a percentage
# keep_n is the thresshold for the max number of words to keep
print(dictionary)
# Out:
# Dictionary(946 unique tokens: ['said', 'commerci', 'experi', 'anoth', 'mean']...)

# %% [markdown]
# Bag of Words

# %%
corpus_bow = [dictionary.doc2bow(text) for text in words_corpus]

# %% [markdown]
# Term Frequency - Inverse Document Frequency

# %%
from gensim import corpora, models
tfidf = models.TfidfModel(corpus_bow)
corpus_tfidf = tfidf[corpus_bow]

# %% [markdown]
# # Data Analysis

# %% [markdown]
# Part of Speech Tagging

# %%
sentence = 'London is the capital and most populous city of England and the United Kingdom'

# %%
sentence_nlp = nlp(sentence)

# POS tagging with Spacy 
spacy_pos_tagged = [(word, word.tag_, word.pos_) for word in sentence_nlp]
pd.DataFrame(spacy_pos_tagged, columns=['Word', 'POS tag', 'Tag type'])

# POS tagging with nltk
#nltk_pos_tagged = nltk.pos_tag(sentence.split())
#pd.DataFrame(nltk_pos_tagged, columns=['Word', 'POS tag'])
# Out:
#         Word POS tag Tag type
# 0     London     NNP    PROPN
# 1         is     VBZ     VERB
# 2        the      DT      DET
# 3    capital      NN     NOUN
# 4        and      CC    CCONJ
# 5       most     RBS      ADV
# 6   populous      JJ      ADJ
# 7       city      NN     NOUN
# 8         of      IN      ADP
# 9    England     NNP    PROPN
# 10       and      CC    CCONJ
# 11       the      DT      DET
# 12    United     NNP    PROPN
# 13   Kingdom     NNP    PROPN

# %% [markdown]
# Similarity

# %%
ntopics = 5
lsi = models.LsiModel(corpus_bow, id2word=dictionary, num_topics=ntopics)
query = sentence
vec_bow = dictionary.doc2bow(query.lower().split())
vec_lsi = lsi[vec_bow]
print(vec_lsi)
index = similarities.MatrixSimilarity(lsi[corpus_bow])
sims = index[vec_lsi]
# Out:
# [(0, 0.00085131237994497241), (1, 0.00069987416087106925), (2, 0.00066518022595611842), (3, -0.00085879260106345458), (4, 0.00081295455190172512)]

# %% [markdown]
# # What are the topics?

# %%
for ki in range(ntopics):
    print("Topic %d: %s\n" % (ki, lsi.print_topic(ki)))
# Out:
# Topic 0: 0.910*"flight" + 0.222*"cancel" + 0.111*"delay" + 0.106*"hour" + 0.092*"flightl" + 0.078*"thank" + 0.077*"help" + 0.076*"time" + 0.065*"late" + 0.060*"book"
#
# Topic 1: 0.523*"thank" + 0.376*"servic" + 0.357*"custom" + 0.253*"hour" + -0.248*"flight" + 0.210*"help" + 0.184*"call" + 0.165*"time" + 0.158*"wait" + 0.134*"hold"
#
# Topic 2: 0.800*"thank" + -0.345*"hour" + -0.186*"servic" + -0.184*"custom" + -0.174*"hold" + -0.165*"call" + -0.160*"wait" + -0.112*"delay" + -0.104*"time" + -0.089*"plane"
#
# Topic 3: 0.522*"servic" + 0.512*"custom" + -0.480*"hour" + -0.234*"delay" + -0.162*"wait" + -0.159*"time" + -0.142*"thank" + -0.141*"plane" + -0.132*"hold" + 0.124*"cancel"
#
# Topic 4: -0.520*"help" + 0.430*"delay" + -0.356*"cancel" + -0.291*"call" + -0.246*"flightl" + 0.183*"servic" + -0.175*"need" + 0.159*"custom" + -0.153*"hold" + 0.139*"hour"

# %% [markdown]
# # Topic Modeling

# %% [markdown]
# Topic modeling using Bag of Words

# %%
lda_model = models.LdaMulticore(corpus_bow, num_topics=10, id2word=dictionary, passes=2, workers=2)
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.059*"flight" + 0.027*"custom" + 0.023*"work" + 0.023*"servic" + 0.019*"cancel" + 0.015*"time" + 0.015*"phone" + 0.015*"miss" + 0.013*"jetblu" + 0.012*"hang"
# Topic: 1
# Words: 0.053*"flight" + 0.030*"hour" + 0.029*"like" + 0.026*"need" + 0.024*"chang" + 0.019*"hold" + 0.015*"want" + 0.014*"help" + 0.013*"seat" + 0.013*"pleas"
# Topic: 2
# Words: 0.085*"flight" + 0.021*"cancel" + 0.017*"good" + 0.016*"hour" + 0.015*"flightl" + 0.015*"wait" + 0.014*"first" + 0.014*"crew" + 0.013*"seat" + 0.012*"take"
# Topic: 3
# Words: 0.092*"thank" + 0.027*"time" + 0.024*"help" + 0.021*"flight" + 0.019*"plane" + 0.018*"hour" + 0.016*"book" + 0.014*"problem" + 0.013*"agent" + 0.013*"call"
# Topic: 4
# Words: 0.033*"call" + 0.025*"flight" + 0.021*"luggag" + 0.019*"gate" + 0.017*"lost" + 0.017*"check" + 0.016*"time" + 0.013*"told" + 0.012*"today" + 0.012*"take"
# Topic: 5
# Words: 0.057*"servic" + 0.044*"custom" + 0.023*"ticket" + 0.016*"would" + 0.013*"flight" + 0.012*"thank" + 0.010*"need" + 0.010*"hour" + 0.010*"help" + 0.009*"great"
# Topic: 6
# Words: 0.021*"back" + 0.018*"help" + 0.015*"sure" + 0.015*"call" + 0.015*"plane" + 0.013*"chang" + 0.013*"reserv" + 0.012*"flight" + 0.012*"thank" + 0.012*"peopl"
# Topic: 7
# Words: 0.037*"wait" + 0.032*"call" + 0.028*"hour" + 0.025*"minut" + 0.025*"delay" + 0.019*"agent" + 0.018*"flight" + 0.017*"gate" + 0.016*"hold" + 0.015*"servic"
# Topic: 8
# Words: 0.185*"flight" + 0.058*"cancel" + 0.027*"delay" + 0.026*"flightl" + 0.021*"thank" + 0.016*"help" + 0.013*"book" + 0.013*"tomorrow" + 0.012*"hour" + 0.010*"need"
# Topic: 9
# Words: 0.030*"airlin" + 0.022*"ever" + 0.022*"custom" + 0.019*"worst" + 0.015*"email" + 0.014*"travel" + 0.013*"even" + 0.013*"sent" + 0.013*"best" + 0.012*"done"

# %%
for index, score in sorted(lda_model[corpus_bow[1]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.6999827027320862
# Topic: 0.030*"airlin" + 0.022*"ever" + 0.022*"custom" + 0.019*"worst" + 0.015*"email" + 0.014*"travel" + 0.013*"even" + 0.013*"sent" + 0.013*"best" + 0.012*"done"
#
# Score: 0.033338334411382675
# Topic: 0.057*"servic" + 0.044*"custom" + 0.023*"ticket" + 0.016*"would" + 0.013*"flight" + 0.012*"thank" + 0.010*"need" + 0.010*"hour" + 0.010*"help" + 0.009*"great"
#
# Score: 0.03333829715847969
# Topic: 0.053*"flight" + 0.030*"hour" + 0.029*"like" + 0.026*"need" + 0.024*"chang" + 0.019*"hold" + 0.015*"want" + 0.014*"help" + 0.013*"seat" + 0.013*"pleas"
#
# Score: 0.03333538398146629
# Topic: 0.033*"call" + 0.025*"flight" + 0.021*"luggag" + 0.019*"gate" + 0.017*"lost" + 0.017*"check" + 0.016*"time" + 0.013*"told" + 0.012*"today" + 0.012*"take"
#
# Score: 0.033334892243146896
# Topic: 0.059*"flight" + 0.027*"custom" + 0.023*"work" + 0.023*"servic" + 0.019*"cancel" + 0.015*"time" + 0.015*"phone" + 0.015*"miss" + 0.013*"jetblu" + 0.012*"hang"
#
# Score: 0.033334773033857346
# Topic: 0.037*"wait" + 0.032*"call" + 0.028*"hour" + 0.025*"minut" + 0.025*"delay" + 0.019*"agent" + 0.018*"flight" + 0.017*"gate" + 0.016*"hold" + 0.015*"servic"
#
# Score: 0.03333449736237526
# Topic: 0.185*"flight" + 0.058*"cancel" + 0.027*"delay" + 0.026*"flightl" + 0.021*"thank" + 0.016*"help" + 0.013*"book" + 0.013*"tomorrow" + 0.012*"hour" + 0.010*"need"
#
# Score: 0.033334050327539444
# Topic: 0.092*"thank" + 0.027*"time" + 0.024*"help" + 0.021*"flight" + 0.019*"plane" + 0.018*"hour" + 0.016*"book" + 0.014*"problem" + 0.013*"agent" + 0.013*"call"
#
# Score: 0.03333354368805885
# Topic: 0.021*"back" + 0.018*"help" + 0.015*"sure" + 0.015*"call" + 0.015*"plane" + 0.013*"chang" + 0.013*"reserv" + 0.012*"flight" + 0.012*"thank" + 0.012*"peopl"
#
# Score: 0.03333351016044617
# Topic: 0.085*"flight" + 0.021*"cancel" + 0.017*"good" + 0.016*"hour" + 0.015*"flightl" + 0.015*"wait" + 0.014*"first" + 0.014*"crew" + 0.013*"seat" + 0.012*"take"

# %% [markdown]
# Topic modeling using TF-IDF

# %%
lda_model_tfidf = models.LdaMulticore(corpus_tfidf, num_topics=10, id2word=dictionary, passes=2, workers=4)
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.014*"flight" + 0.013*"sent" + 0.013*"time" + 0.011*"custom" + 0.010*"servic" + 0.010*"plane" + 0.010*"help" + 0.009*"delay" + 0.009*"thank" + 0.009*"stop"
# Topic: 1 Word: 0.016*"flight" + 0.012*"follow" + 0.011*"help" + 0.010*"thank" + 0.009*"hour" + 0.008*"airway" + 0.008*"delay" + 0.008*"still" + 0.007*"wait" + 0.007*"never"
# Topic: 2 Word: 0.062*"thank" + 0.018*"flight" + 0.016*"pleas" + 0.015*"custom" + 0.014*"servic" + 0.010*"help" + 0.010*"delay" + 0.010*"agent" + 0.008*"cancel" + 0.008*"updat"
# Topic: 3 Word: 0.024*"flight" + 0.013*"call" + 0.012*"tomorrow" + 0.011*"cancel" + 0.011*"hour" + 0.011*"wait" + 0.008*"help" + 0.008*"hold" + 0.008*"reserv" + 0.008*"thank"
# Topic: 4 Word: 0.022*"thank" + 0.013*"still" + 0.013*"much" + 0.012*"gate" + 0.011*"flight" + 0.010*"hour" + 0.010*"servic" + 0.010*"respons" + 0.009*"need" + 0.009*"wait"
# Topic: 5 Word: 0.032*"flight" + 0.014*"cancel" + 0.012*"would" + 0.012*"like" + 0.010*"flightl" + 0.009*"servic" + 0.009*"take" + 0.009*"custom" + 0.009*"look" + 0.008*"delay"
# Topic: 6 Word: 0.018*"flight" + 0.010*"delay" + 0.010*"realli" + 0.009*"hour" + 0.009*"done" + 0.009*"wait" + 0.009*"travel" + 0.009*"alreadi" + 0.008*"pleas" + 0.008*"great"
# Topic: 7 Word: 0.019*"thank" + 0.018*"flight" + 0.014*"check" + 0.012*"good" + 0.012*"seat" + 0.011*"time" + 0.011*"delay" + 0.011*"plane" + 0.009*"hour" + 0.008*"great"
# Topic: 8 Word: 0.019*"flight" + 0.014*"help" + 0.014*"hold" + 0.012*"hour" + 0.012*"fleek" + 0.011*"fleet" + 0.010*"call" + 0.009*"jetblu" + 0.009*"need" + 0.008*"minut"
# Topic: 9 Word: 0.023*"flight" + 0.016*"love" + 0.013*"airlin" + 0.013*"thank" + 0.012*"miss" + 0.011*"worst" + 0.011*"connect" + 0.010*"airport" + 0.008*"hour" + 0.008*"know"

# %%
for index, score in sorted(lda_model_tfidf[corpus_bow[1]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.6999585628509521
# Topic: 0.018*"flight" + 0.010*"delay" + 0.010*"realli" + 0.009*"hour" + 0.009*"done" + 0.009*"wait" + 0.009*"travel" + 0.009*"alreadi" + 0.008*"pleas" + 0.008*"great"
#
# Score: 0.03334273770451546
# Topic: 0.016*"flight" + 0.012*"follow" + 0.011*"help" + 0.010*"thank" + 0.009*"hour" + 0.008*"airway" + 0.008*"delay" + 0.008*"still" + 0.007*"wait" + 0.007*"never"
#
# Score: 0.03334050998091698
# Topic: 0.023*"flight" + 0.016*"love" + 0.013*"airlin" + 0.013*"thank" + 0.012*"miss" + 0.011*"worst" + 0.011*"connect" + 0.010*"airport" + 0.008*"hour" + 0.008*"know"
#
# Score: 0.03333885222673416
# Topic: 0.019*"thank" + 0.018*"flight" + 0.014*"check" + 0.012*"good" + 0.012*"seat" + 0.011*"time" + 0.011*"delay" + 0.011*"plane" + 0.009*"hour" + 0.008*"great"
#
# Score: 0.033338066190481186
# Topic: 0.014*"flight" + 0.013*"sent" + 0.013*"time" + 0.011*"custom" + 0.010*"servic" + 0.010*"plane" + 0.010*"help" + 0.009*"delay" + 0.009*"thank" + 0.009*"stop"
#
# Score: 0.033337753266096115
# Topic: 0.022*"thank" + 0.013*"still" + 0.013*"much" + 0.012*"gate" + 0.011*"flight" + 0.010*"hour" + 0.010*"servic" + 0.010*"respons" + 0.009*"need" + 0.009*"wait"
#
# Score: 0.03333655372262001
# Topic: 0.032*"flight" + 0.014*"cancel" + 0.012*"would" + 0.012*"like" + 0.010*"flightl" + 0.009*"servic" + 0.009*"take" + 0.009*"custom" + 0.009*"look" + 0.008*"delay"
#
# Score: 0.0333360955119133
# Topic: 0.024*"flight" + 0.013*"call" + 0.012*"tomorrow" + 0.011*"cancel" + 0.011*"hour" + 0.011*"wait" + 0.008*"help" + 0.008*"hold" + 0.008*"reserv" + 0.008*"thank"
#
# Score: 0.03333552926778793
# Topic: 0.062*"thank" + 0.018*"flight" + 0.016*"pleas" + 0.015*"custom" + 0.014*"servic" + 0.010*"help" + 0.010*"delay" + 0.010*"agent" + 0.008*"cancel" + 0.008*"updat"
#
# Score: 0.03333533927798271
# Topic: 0.019*"flight" + 0.014*"help" + 0.014*"hold" + 0.012*"hour" + 0.012*"fleek" + 0.011*"fleet" + 0.010*"call" + 0.009*"jetblu" + 0.009*"need" + 0.008*"minut"

# %% [markdown]
# # Sentiment

# %%
#find sentiment vader
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-3042500bd17c> in <module>()
#       1 #find sentiment vader
# ----> 2 from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
#       3 analyser = SentimentIntensityAnalyzer()
#
# ModuleNotFoundError: No module named 'vaderSentiment'

# %%
snt = analyser.polarity_scores('This is an examle of a happy tweet')
print(snt['compound'])
